# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/million-headlines/abcnews-date-text.csv
# /kaggle/input/india-headlines-news-dataset/india-news-headlines.csv

# %%
from transformers import pipeline
# Out:
# 2021-10-01 11:12:01.462557: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0

# %%
classifier = pipeline("zero-shot-classification", device=0)
# Out:
# Downloading:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/26.0 [00:00<?, ?B/s]

# %%
headlines=pd.read_csv('../input/million-headlines/abcnews-date-text.csv')

# %%
headlines.head()
# Out:
#    publish_date                                      headline_text
# 0      20030219  aba decides against community broadcasting lic...
# 1      20030219     act fire witnesses must be aware of defamation
# 2      20030219     a g calls for infrastructure protection summit
# 3      20030219           air nz staff in aust strike for pay rise
# 4      20030219      air nz strike to affect australian travellers

# %%
samples=headlines['headline_text'][:100]
samples
# Out:
# 0     aba decides against community broadcasting lic...
# 1        act fire witnesses must be aware of defamation
# 2        a g calls for infrastructure protection summit
# 3              air nz staff in aust strike for pay rise
# 4         air nz strike to affect australian travellers
#                             ...
# 95             meeting to consider tick clearance costs
# 96           meeting to focus on broken hill water woes
# 97                        moderate lift in wages growth
# 98        more than 40 pc of young men drink alcohol at
# 99    more water restrictions predicted for northern...
# Name: headline_text, Length: 100, dtype: object

# %%
strings = samples.values

# %%
sequence = list(strings)

# %% [markdown]
# # Classification

# %%
candidate_labels = ["politics", "finance", "sports",'entertainment']

# %%
classifier(sequence, candidate_labels)
# Out:
# [{'sequence': 'aba decides against community broadcasting licence',
#   'labels': ['politics', 'entertainment', 'finance', 'sports'],
#   'scores': [0.4393872022628784,
#    0.2249700129032135,
#    0.2175971418619156,
#    0.11804560571908951]},
#  {'sequence': 'act fire witnesses must be aware of defamation',
#   'labels': ['politics', 'entertainment', 'finance', 'sports'],
#   'scores': [0.2959381937980652,
#    0.26817604899406433,
#    0.2557956874370575,
#    0.18009011447429657]},
#  {'sequence': 'a g calls for infrastructure protection summit',
#   'labels': ['politics', 'finance', 'entertainment', 'sports'],
#   'scores': [0.4671441912651062,
#    0.38238033652305603,
#    0.07862333208322525,
#    0.0718521699309349]},
#  {'sequence': 'air nz staff in aust strike for pay rise',
#   'labels': ['finance', 'politics', 'entertainment', 'sports'],
#   'scores': [0.4542310833930969,
#    0.23139575123786926,
#    0.2238190919160843,
#    0.09055406600236893]},
#  {'sequence': 'air nz strike to affect australian travellers',
#   'labels': ['entertainment', 'politics', 'finance', 'sports'],
#   'scores': [0.36987394094467163,
#    0.28730517625808716,
#    0.19934354722499847,
#    0.14347730576992035]},
#  {'sequence': 'ambitious olsson wins triple jump',
#   'labels': ['sports', 'entertainment', 'politics', 'finance'],
#   'scores': [0.9359449148178101,
#    0.05218726024031639,
#    0.006619627587497234,
#    0.005248192697763443]},
#  {'sequence': 'antic delighted with record breaking barca',
#   'labels': ['entertainment', 'sports', 'finance', 'politics'],
#   'scores': [0.824622392654419,
#    0.13382922112941742,
#    0.03351229056715965,
#    0.008036162704229355]},
#  {'sequence': 'aussie qualifier stosur wastes four memphis match',
#   'labels': ['sports', 'entertainment', 'politics', 'finance'],
#   'scores': [0.7809566855430603,
#    0.11396433413028717,
#    0.05683106556534767,
#    0.04824791103601456]},
#  {'sequence': 'aust addresses un security council over iraq',
#   'labels': ['politics', 'finance', 'entertainment', 'sports'],
#   'scores': [0.5729578137397766,
#    0.14964953064918518,
#    0.14922605454921722,
#    0.1281665861606598]},
#  {'sequence': 'australia is locked into war timetable opp',
#   'labels': ['politics', 'finance', 'entertainment', 'sports'],
#   'scores': [0.8248786330223083,
#    0.0644579529762268,
#    0.05890640243887901,
#    0.05175697058439255]},
#  {'sequence': 'australia to contribute 10 million in aid to iraq',
#   'labels': ['finance', 'entertainment', 'politics', 'sports'],
#   'scores': [0.749135434627533,
#    0.09876652806997299,
#    0.09837650507688522,
#    0.05372152850031853]},
#  {'sequence': 'barca take record as robson celebrates birthday in',
#   'labels': ['sports', 'finance', 'entertainment', 'politics'],
#   'scores': [0.7204535603523254,
#    0.13317888975143433,
#    0.07482382655143738,
#    0.07154372334480286]},
#  {'sequence': 'bathhouse plans move ahead',
#   'labels': ['entertainment', 'finance', 'politics', 'sports'],
#   'scores': [0.6802303791046143,
#    0.16981282830238342,
#    0.07669319212436676,
#    0.07326365262269974]},
#  {'sequence': 'big hopes for launceston cycling championship',
#   'labels': ['sports', 'entertainment', 'finance', 'politics'],
#   'scores': [0.9709654450416565,
#    0.02056257426738739,
#    0.005252274218946695,
#    0.0032196815591305494]},
#  {'sequence': 'big plan to boost paroo water supplies',
#   'labels': ['entertainment', 'finance', 'politics', 'sports'],
#   'scores': [0.3412102162837982,
#    0.22952532768249512,
#    0.21692390739917755,
#    0.2123405784368515]},
#  {'sequence': 'blizzard buries united states in bills',
#   'labels': ['finance', 'politics', 'entertainment', 'sports'],
#   'scores': [0.5007787346839905,
#    0.2570643723011017,
#    0.1619720160961151,
#    0.08018486946821213]},
#  {'sequence': 'brigadier dismisses reports troops harassed in',
#   'labels': ['politics', 'entertainment', 'finance', 'sports'],
#   'scores': [0.4822372794151306,
#    0.2686677873134613,
#    0.16124796867370605,
#    0.08784697204828262]},
#  {'sequence': 'british combat troops arriving daily in kuwait',
#   'labels': ['entertainment', 'finance', 'sports', 'politics'],
#   'scores': [0.33495816588401794,
#    0.22769688069820404,
#    0.22574183344841003,
#    0.21160317957401276]},
#  {'sequence': 'bryant leads lakers to double overtime win',
#   'labels': ['sports', 'entertainment', 'finance', 'politics'],
#   'scores': [0.9165587425231934,
#    0.06721760332584381,
#    0.012145625427365303,
#    0.004077987279742956]},
#  {'sequence': 'bushfire victims urged to see centrelink',
#   'labels': ['finance', 'entertainment', 'sports', 'politics'],
#   'scores': [0.7461159229278564,
#    0.1319379061460495,
#    0.06926024705171585,
#    0.052685920149087906]},
#  {'sequence': 'businesses should prepare for terrorist attacks',
#   'labels': ['finance', 'politics', 'sports', 'entertainment'],
#   'scores': [0.6673349738121033,
#    0.11760419607162476,
#    0.10830451548099518,
#    0.1067563146352768]},
#  {'sequence': 'calleri avenges final defeat to eliminate massu',
#   'labels': ['politics', 'sports', 'entertainment', 'finance'],
#   'scores': [0.43359100818634033,
#    0.3490482568740845,
#    0.12856750190258026,
#    0.0887933000922203]},
#  {'sequence': 'call for ethanol blend fuel to go ahead',
#   'labels': ['finance', 'politics', 'entertainment', 'sports'],
#   'scores': [0.4687844216823578,
#    0.324274480342865,
#    0.15741455554962158,
#    0.04952654242515564]},
#  {'sequence': 'carews freak goal leaves roma in ruins',
#   'labels': ['sports', 'entertainment', 'finance', 'politics'],
#   'scores': [0.7995122671127319,
#    0.11906076967716217,
#    0.05247389152646065,
#    0.028953054919838905]},
#  {'sequence': 'cemeteries miss out on funds',
#   'labels': ['finance', 'politics', 'sports', 'entertainment'],
#   'scores': [0.85634845495224,
#    0.06123091280460358,
#    0.045477017760276794,
#    0.03694356232881546]},
#  {'sequence': 'code of conduct toughens organ donation regulations',
#   'labels': ['politics', 'entertainment', 'finance', 'sports'],
#   'scores': [0.2816963195800781,
#    0.2731899321079254,
#    0.25620052218437195,
#    0.18891321122646332]},
#  {'sequence': 'commonwealth bank cuts fixed home loan rates',
#   'labels': ['finance', 'entertainment', 'sports', 'politics'],
#   'scores': [0.9493934512138367,
#    0.03643187880516052,
#    0.007764035370200872,
#    0.006410625763237476]},
#  {'sequence': 'community urged to help homeless youth',
#   'labels': ['entertainment', 'finance', 'politics', 'sports'],
#   'scores': [0.37398549914360046,
#    0.2918175756931305,
#    0.1811409294605255,
#    0.15305602550506592]},
#  {'sequence': 'council chief executive fails to secure position',
#   'labels': ['politics', 'finance', 'entertainment', 'sports'],
#   'scores': [0.7175761461257935,
#    0.16968892514705658,
#    0.0780324712395668,
#    0.034702498465776443]},
#  {'sequence': 'councillor to contest wollongong as independent',
#   'labels': ['politics', 'entertainment', 'finance', 'sports'],
#   'scores': [0.9530335068702698,
#    0.028490323573350906,
#    0.011806978844106197,
#    0.00666921166703105]},
#  {'sequence': 'council moves to protect tas heritage garden',
#   'labels': ['politics', 'entertainment', 'finance', 'sports'],
#   'scores': [0.5685899257659912,
#    0.18859991431236267,
#    0.1330617070198059,
#    0.10974837839603424]},
#  {'sequence': 'council welcomes ambulance levy decision',
#   'labels': ['finance', 'entertainment', 'politics', 'sports'],
#   'scores': [0.4238998591899872,
#    0.29417064785957336,
#    0.22464458644390106,
#    0.05728486180305481]},
#  {'sequence': 'council welcomes insurance breakthrough',
#   'labels': ['finance', 'entertainment', 'politics', 'sports'],
#   'scores': [0.669231116771698,
#    0.14068736135959625,
#    0.12939853966236115,
#    0.06068296730518341]},
#  {'sequence': 'crean tells alp leadership critics to shut up',
#   'labels': ['politics', 'entertainment', 'sports', 'finance'],
#   'scores': [0.8548503518104553,
#    0.08151771873235703,
#    0.03510069102048874,
#    0.028531162068247795]},
#  {'sequence': 'dargo fire threat expected to rise',
#   'labels': ['finance', 'sports', 'politics', 'entertainment'],
#   'scores': [0.2945147752761841,
#    0.24069994688034058,
#    0.23456481099128723,
#    0.2302205115556717]},
#  {'sequence': 'death toll continues to climb in south korean subway',
#   'labels': ['finance', 'sports', 'politics', 'entertainment'],
#   'scores': [0.3208787441253662,
#    0.2565995454788208,
#    0.25000497698783875,
#    0.17251673340797424]},
#  {'sequence': 'dems hold plebiscite over iraqi conflict',
#   'labels': ['politics', 'entertainment', 'finance', 'sports'],
#   'scores': [0.9452717900276184,
#    0.03104378469288349,
#    0.013216719962656498,
#    0.010467750951647758]},
#  {'sequence': 'dent downs philippoussis in tie break thriller',
#   'labels': ['entertainment', 'sports', 'politics', 'finance'],
#   'scores': [0.883137583732605,
#    0.08156198263168335,
#    0.019948318600654602,
#    0.015352094545960426]},
#  {'sequence': 'de villiers to learn fate on march 5',
#   'labels': ['politics', 'entertainment', 'sports', 'finance'],
#   'scores': [0.49283620715141296,
#    0.18963435292243958,
#    0.1654394268989563,
#    0.15208999812602997]},
#  {'sequence': 'digital tv will become commonplace summit',
#   'labels': ['entertainment', 'sports', 'finance', 'politics'],
#   'scores': [0.625656008720398,
#    0.14344832301139832,
#    0.13486911356449127,
#    0.09602656960487366]},
#  {'sequence': 'direct anger at govt not soldiers crean urges',
#   'labels': ['politics', 'finance', 'entertainment', 'sports'],
#   'scores': [0.8222115635871887,
#    0.07035009562969208,
#    0.06238962337374687,
#    0.045048631727695465]},
#  {'sequence': 'dispute over at smithton vegetable processing plant',
#   'labels': ['entertainment', 'sports', 'finance', 'politics'],
#   'scores': [0.4826488196849823,
#    0.20826618373394012,
#    0.1580100804567337,
#    0.15107490122318268]},
#  {'sequence': 'dog mauls 18 month old toddler in nsw',
#   'labels': ['entertainment', 'finance', 'sports', 'politics'],
#   'scores': [0.330729216337204,
#    0.293491005897522,
#    0.19921648502349854,
#    0.1765632927417755]},
#  {'sequence': 'dying korean subway passengers phoned for help',
#   'labels': ['entertainment', 'sports', 'finance', 'politics'],
#   'scores': [0.3319852650165558,
#    0.26249074935913086,
#    0.23945046961307526,
#    0.1660735160112381]},
#  {'sequence': 'england change three for wales match',
#   'labels': ['sports', 'politics', 'entertainment', 'finance'],
#   'scores': [0.771978497505188,
#    0.09524070471525192,
#    0.09362282603979111,
#    0.03915795683860779]},
#  {'sequence': 'epa still trying to recover chemical clean up costs',
#   'labels': ['finance', 'politics', 'entertainment', 'sports'],
#   'scores': [0.8401366472244263,
#    0.10769250988960266,
#    0.03180818259716034,
#    0.020362643525004387]},
#  {'sequence': 'expressions of interest sought to build livestock',
#   'labels': ['entertainment', 'sports', 'finance', 'politics'],
#   'scores': [0.6945857405662537,
#    0.1223655715584755,
#    0.12007362395524979,
#    0.06297508627176285]},
#  {'sequence': 'fed opp to re introduce national insurance',
#   'labels': ['politics', 'finance', 'entertainment', 'sports'],
#   'scores': [0.8305536508560181,
#    0.11591890454292297,
#    0.04322956129908562,
#    0.010297859087586403]},
#  {'sequence': 'firefighters contain acid spill',
#   'labels': ['entertainment', 'sports', 'finance', 'politics'],
#   'scores': [0.480756938457489,
#    0.2168995440006256,
#    0.17063546180725098,
#    0.131708025932312]},
#  {'sequence': 'four injured in head on highway crash',
#   'labels': ['entertainment', 'sports', 'finance', 'politics'],
#   'scores': [0.36625561118125916,
#    0.2561437785625458,
#    0.2112666815519333,
#    0.1663338541984558]},
#  {'sequence': 'freedom records net profit for third successive',
#   'labels': ['finance', 'entertainment', 'politics', 'sports'],
#   'scores': [0.5618282556533813,
#    0.2839592397212982,
#    0.09860947728157043,
#    0.055603086948394775]},
#  {'sequence': 'funds allocated for domestic violence victims',
#   'labels': ['finance', 'sports', 'politics', 'entertainment'],
#   'scores': [0.9500306844711304,
#    0.01838202401995659,
#    0.01648435927927494,
#    0.015102884732186794]},
#  {'sequence': 'funds allocated for youth at risk',
#   'labels': ['finance', 'politics', 'entertainment', 'sports'],
#   'scores': [0.9556871056556702,
#    0.015612930990755558,
#    0.014783105812966824,
#    0.01391682866960764]},
#  {'sequence': 'funds announced for bridge work',
#   'labels': ['finance', 'entertainment', 'politics', 'sports'],
#   'scores': [0.9786473512649536,
#    0.007968449033796787,
#    0.006781958043575287,
#    0.006602261681109667]},
#  {'sequence': 'funds to go to cadell upgrade',
#   'labels': ['finance', 'sports', 'entertainment', 'politics'],
#   'scores': [0.9609137177467346,
#    0.015223977155983448,
#    0.01304604858160019,
#    0.01081620529294014]},
#  {'sequence': 'funds to help restore cossack',
#   'labels': ['finance', 'politics', 'sports', 'entertainment'],
#   'scores': [0.9456237554550171,
#    0.025781363248825073,
#    0.014499833807349205,
#    0.014095168560743332]},
#  {'sequence': 'german court to give verdict on sept 11 accused',
#   'labels': ['politics', 'entertainment', 'finance', 'sports'],
#   'scores': [0.36223721504211426,
#    0.28482484817504883,
#    0.2228473722934723,
#    0.13009053468704224]},
#  {'sequence': 'gilchrist backs rest policy',
#   'labels': ['politics', 'entertainment', 'finance', 'sports'],
#   'scores': [0.4362325072288513,
#    0.196419820189476,
#    0.1870296597480774,
#    0.1803179532289505]},
#  {'sequence': 'girl injured in head on highway crash',
#   'labels': ['entertainment', 'sports', 'finance', 'politics'],
#   'scores': [0.40499481558799744,
#    0.2533004581928253,
#    0.18848606944084167,
#    0.15321865677833557]},
#  {'sequence': 'gold coast to hear about bilby project',
#   'labels': ['entertainment', 'finance', 'sports', 'politics'],
#   'scores': [0.44102129340171814,
#    0.3463674783706665,
#    0.14327256381511688,
#    0.06933864951133728]},
#  {'sequence': 'golf club feeling smoking ban impact',
#   'labels': ['sports', 'entertainment', 'finance', 'politics'],
#   'scores': [0.9800291061401367,
#    0.009734160266816616,
#    0.005813075695186853,
#    0.004423694219440222]},
#  {'sequence': 'govt is to blame for ethanols unpopularity opp',
#   'labels': ['politics', 'finance', 'entertainment', 'sports'],
#   'scores': [0.8986208438873291,
#    0.06462600082159042,
#    0.02195269800722599,
#    0.014800459146499634]},
#  {'sequence': 'greens offer police station alternative',
#   'labels': ['entertainment', 'politics', 'finance', 'sports'],
#   'scores': [0.5595048666000366,
#    0.1962643265724182,
#    0.1376250982284546,
#    0.10660570859909058]},
#  {'sequence': 'griffiths under fire over project knock back',
#   'labels': ['politics', 'finance', 'entertainment', 'sports'],
#   'scores': [0.6815325617790222,
#    0.13698001205921173,
#    0.10729997605085373,
#    0.07418742775917053]},
#  {'sequence': 'group to meet in north west wa over rock art',
#   'labels': ['entertainment', 'sports', 'politics', 'finance'],
#   'scores': [0.7908329367637634,
#    0.0936516746878624,
#    0.059272944927215576,
#    0.0562424510717392]},
#  {'sequence': 'hacker gains access to eight million credit cards',
#   'labels': ['finance', 'entertainment', 'sports', 'politics'],
#   'scores': [0.9242660999298096,
#    0.04127759486436844,
#    0.020486358553171158,
#    0.013969970867037773]},
#  {'sequence': 'hanson is grossly naive over nsw issues costa',
#   'labels': ['finance', 'politics', 'entertainment', 'sports'],
#   'scores': [0.7818957567214966,
#    0.12973728775978088,
#    0.056936878710985184,
#    0.03143008053302765]},
#  {'sequence': 'hanson should go back where she came from nsw mp',
#   'labels': ['politics', 'entertainment', 'finance', 'sports'],
#   'scores': [0.6630858182907104,
#    0.1626574844121933,
#    0.10506679117679596,
#    0.06918986886739731]},
#  {'sequence': 'harrington raring to go after break',
#   'labels': ['entertainment', 'politics', 'sports', 'finance'],
#   'scores': [0.36325597763061523,
#    0.3137471079826355,
#    0.2636978030204773,
#    0.059299029409885406]},
#  {'sequence': 'health minister backs organ and tissue storage',
#   'labels': ['politics', 'finance', 'entertainment', 'sports'],
#   'scores': [0.6546322107315063,
#    0.14175616204738617,
#    0.11490906029939651,
#    0.08870256692171097]},
#  {'sequence': 'heavy metal deposits survey nearing end',
#   'labels': ['entertainment', 'finance', 'sports', 'politics'],
#   'scores': [0.42999351024627686,
#    0.22288374602794647,
#    0.18328334391117096,
#    0.16383935511112213]},
#  {'sequence': 'injured rios pulls out of buenos aires open',
#   'labels': ['entertainment', 'sports', 'politics', 'finance'],
#   'scores': [0.48372477293014526,
#    0.3992457091808319,
#    0.059769656509160995,
#    0.05725980922579765]},
#  {'sequence': 'inquest finds mans death accidental',
#   'labels': ['sports', 'entertainment', 'finance', 'politics'],
#   'scores': [0.32314079999923706,
#    0.27796363830566406,
#    0.23504771292209625,
#    0.16384780406951904]},
#  {'sequence': 'investigations underway into death toll of korean',
#   'labels': ['politics', 'finance', 'sports', 'entertainment'],
#   'scores': [0.2764238715171814,
#    0.27451056241989136,
#    0.2690574526786804,
#    0.18000808358192444]},
#  {'sequence': 'investigation underway into elster creek spill',
#   'labels': ['finance', 'sports', 'entertainment', 'politics'],
#   'scores': [0.3112659156322479,
#    0.29353246092796326,
#    0.2616259455680847,
#    0.1335756927728653]},
#  {'sequence': 'iraqs neighbours plead for continued un inspections',
#   'labels': ['entertainment', 'politics', 'finance', 'sports'],
#   'scores': [0.3280220925807953,
#    0.29883599281311035,
#    0.21445414423942566,
#    0.1586877405643463]},
#  {'sequence': 'iraq to pay for own rebuilding white house',
#   'labels': ['finance', 'politics', 'entertainment', 'sports'],
#   'scores': [0.8792077898979187,
#    0.07216431200504303,
#    0.033646151423454285,
#    0.014981791377067566]},
#  {'sequence': 'irish man arrested over omagh bombing',
#   'labels': ['entertainment', 'politics', 'finance', 'sports'],
#   'scores': [0.3268519937992096,
#    0.29956746101379395,
#    0.19510549306869507,
#    0.17847506701946259]},
#  {'sequence': 'irrigators vote over river management',
#   'labels': ['politics', 'entertainment', 'finance', 'sports'],
#   'scores': [0.8264132142066956,
#    0.0810541883111,
#    0.05053888261318207,
#    0.041993673890829086]},
#  {'sequence': 'israeli forces push into gaza strip',
#   'labels': ['politics', 'entertainment', 'sports', 'finance'],
#   'scores': [0.7188330292701721,
#    0.09730546176433563,
#    0.09523506462574005,
#    0.08862646669149399]},
#  {'sequence': 'jury to consider verdict in murder case',
#   'labels': ['sports', 'finance', 'entertainment', 'politics'],
#   'scores': [0.26064127683639526,
#    0.25092288851737976,
#    0.24854393303394318,
#    0.2398918718099594]},
#  {'sequence': 'juvenile sex offenders unlikely to reoffend as',
#   'labels': ['entertainment', 'finance', 'politics', 'sports'],
#   'scores': [0.3874698877334595,
#    0.32268160581588745,
#    0.1748054325580597,
#    0.11504301428794861]},
#  {'sequence': 'kelly disgusted at alleged bp ethanol scare',
#   'labels': ['politics', 'finance', 'entertainment', 'sports'],
#   'scores': [0.47402435541152954,
#    0.22719743847846985,
#    0.15252932906150818,
#    0.146248921751976]},
#  {'sequence': 'kelly not surprised ethanol confidence low',
#   'labels': ['entertainment', 'finance', 'politics', 'sports'],
#   'scores': [0.3238777220249176,
#    0.285983681678772,
#    0.2158503383398056,
#    0.17428822815418243]},
#  {'sequence': 'korean subway fire 314 still missing',
#   'labels': ['entertainment', 'finance', 'sports', 'politics'],
#   'scores': [0.4120136499404907,
#    0.20783226191997528,
#    0.19780267775058746,
#    0.18235135078430176]},
#  {'sequence': 'last minute call hands alinghi big lead',
#   'labels': ['sports', 'entertainment', 'politics', 'finance'],
#   'scores': [0.4993862807750702,
#    0.20421718060970306,
#    0.16827906668186188,
#    0.1281174123287201]},
#  {'sequence': 'low demand forces air service cuts',
#   'labels': ['entertainment', 'finance', 'politics', 'sports'],
#   'scores': [0.32185596227645874,
#    0.31470850110054016,
#    0.2202509343624115,
#    0.1431846171617508]},
#  {'sequence': 'man arrested after central qld hijack attempt',
#   'labels': ['finance', 'entertainment', 'sports', 'politics'],
#   'scores': [0.33845579624176025,
#    0.3322350084781647,
#    0.1941099315881729,
#    0.13519923388957977]},
#  {'sequence': 'man charged over cooma murder',
#   'labels': ['sports', 'finance', 'politics', 'entertainment'],
#   'scores': [0.29328492283821106,
#    0.2602747678756714,
#    0.22670218348503113,
#    0.2197382003068924]},
#  {'sequence': 'man fined after aboriginal tent embassy raid',
#   'labels': ['politics', 'finance', 'entertainment', 'sports'],
#   'scores': [0.358704537153244,
#    0.2872200608253479,
#    0.22372373938560486,
#    0.1303516924381256]},
#  {'sequence': 'man jailed over keno fraud',
#   'labels': ['finance', 'entertainment', 'sports', 'politics'],
#   'scores': [0.6810488700866699,
#    0.13053147494792938,
#    0.09898319095373154,
#    0.08943644165992737]},
#  {'sequence': 'man with knife hijacks light plane',
#   'labels': ['entertainment', 'sports', 'politics', 'finance'],
#   'scores': [0.5605358481407166,
#    0.1992439478635788,
#    0.13012884557247162,
#    0.11009138077497482]},
#  {'sequence': 'martin to lobby against losing nt seat in fed',
#   'labels': ['politics', 'entertainment', 'finance', 'sports'],
#   'scores': [0.8803824782371521,
#    0.06533385813236237,
#    0.03323492035269737,
#    0.02104872278869152]},
#  {'sequence': 'massive drug crop discovered in western nsw',
#   'labels': ['entertainment', 'sports', 'finance', 'politics'],
#   'scores': [0.32860347628593445,
#    0.3041691184043884,
#    0.19947895407676697,
#    0.16774846613407135]},
#  {'sequence': 'mayor warns landfill protesters',
#   'labels': ['politics', 'finance', 'entertainment', 'sports'],
#   'scores': [0.8013741970062256,
#    0.07390213757753372,
#    0.07039900869131088,
#    0.054324567317962646]},
#  {'sequence': 'meeting to consider tick clearance costs',
#   'labels': ['finance', 'politics', 'entertainment', 'sports'],
#   'scores': [0.750244140625,
#    0.12339986860752106,
#    0.07191801071166992,
#    0.05443790927529335]},
#  {'sequence': 'meeting to focus on broken hill water woes',
#   'labels': ['entertainment', 'politics', 'sports', 'finance'],
#   'scores': [0.30392029881477356,
#    0.26338037848472595,
#    0.22356881201267242,
#    0.20913052558898926]},
#  {'sequence': 'moderate lift in wages growth',
#   'labels': ['entertainment', 'finance', 'politics', 'sports'],
#   'scores': [0.3835863471031189,
#    0.33998915553092957,
#    0.1846262812614441,
#    0.09179823100566864]},
#  {'sequence': 'more than 40 pc of young men drink alcohol at',
#   'labels': ['entertainment', 'finance', 'politics', 'sports'],
#   'scores': [0.6553784608840942,
#    0.16640861332416534,
#    0.10392822325229645,
#    0.07428470999002457]},
#  {'sequence': 'more water restrictions predicted for northern tas',
#   'labels': ['finance', 'entertainment', 'sports', 'politics'],
#   'scores': [0.4184572398662567,
#    0.23209407925605774,
#    0.20592795312404633,
#    0.1435207724571228]}]

# %% [markdown]
# # Sentiment Analysis

# %%
sentiment_labels = ['positive','negative']

# %%
sent = classifier(sequence, sentiment_labels)

# %%
sent
# Out:
# [{'sequence': 'aba decides against community broadcasting licence',
#   'labels': ['negative', 'positive'],
#   'scores': [0.9875787496566772, 0.012421278282999992]},
#  {'sequence': 'act fire witnesses must be aware of defamation',
#   'labels': ['negative', 'positive'],
#   'scores': [0.99607253074646, 0.003927450627088547]},
#  {'sequence': 'a g calls for infrastructure protection summit',
#   'labels': ['negative', 'positive'],
#   'scores': [0.609847366809845, 0.39015260338783264]},
#  {'sequence': 'air nz staff in aust strike for pay rise',
#   'labels': ['negative', 'positive'],
#   'scores': [0.935452938079834, 0.06454705446958542]},
#  {'sequence': 'air nz strike to affect australian travellers',
#   'labels': ['negative', 'positive'],
#   'scores': [0.9901187419891357, 0.009881260804831982]},
#  {'sequence': 'ambitious olsson wins triple jump',
#   'labels': ['positive', 'negative'],
#   'scores': [0.9616014361381531, 0.03839854896068573]},
#  {'sequence': 'antic delighted with record breaking barca',
#   'labels': ['positive', 'negative'],
#   'scores': [0.9938040375709534, 0.006195938680320978]},
#  {'sequence': 'aussie qualifier stosur wastes four memphis match',
#   'labels': ['negative', 'positive'],
#   'scores': [0.9845432043075562, 0.015456846915185452]},
#  {'sequence': 'aust addresses un security council over iraq',
#   'labels': ['negative', 'positive'],
#   'scores': [0.5623589754104614, 0.4376409947872162]},
#  {'sequence': 'australia is locked into war timetable opp',
#   'labels': ['negative', 'positive'],
#   'scores': [0.9903814196586609, 0.009618598967790604]},
#  {'sequence': 'australia to contribute 10 million in aid to iraq',
#   'labels': ['positive', 'negative'],
#   'scores': [0.8200084567070007, 0.17999151349067688]},
#  {'sequence': 'barca take record as robson celebrates birthday in',
#   'labels': ['negative', 'positive'],
#   'scores': [0.5954985022544861, 0.4045014977455139]},
#  {'sequence': 'bathhouse plans move ahead',
#   'labels': ['positive', 'negative'],
#   'scores': [0.983198881149292, 0.016801150515675545]},
#  {'sequence': 'big hopes for launceston cycling championship',
#   'labels': ['positive', 'negative'],
#   'scores': [0.9806583523750305, 0.019341599196195602]},
#  {'sequence': 'big plan to boost paroo water supplies',
#   'labels': ['positive', 'negative'],
#   'scores': [0.9547746181488037, 0.045225437730550766]},
#  {'sequence': 'blizzard buries united states in bills',
#   'labels': ['negative', 'positive'],
#   'scores': [0.9827327132225037, 0.017267275601625443]},
#  {'sequence': 'brigadier dismisses reports troops harassed in',
#   'labels': ['negative', 'positive'],
#   'scores': [0.9709593057632446, 0.029040692374110222]},
#  {'sequence': 'british combat troops arriving daily in kuwait',
#   'labels': ['positive', 'negative'],
#   'scores': [0.5830335021018982, 0.4169664978981018]},
#  {'sequence': 'bryant leads lakers to double overtime win',
#   'labels': ['positive', 'negative'],
#   'scores': [0.9828169941902161, 0.017183011397719383]},
#  {'sequence': 'bushfire victims urged to see centrelink',
#   'labels': ['negative', 'positive'],
#   'scores': [0.8899672031402588, 0.11003272980451584]},
#  {'sequence': 'businesses should prepare for terrorist attacks',
#   'labels': ['negative', 'positive'],
#   'scores': [0.7388364672660828, 0.2611635625362396]},
#  {'sequence': 'calleri avenges final defeat to eliminate massu',
#   'labels': ['positive', 'negative'],
#   'scores': [0.5700154900550842, 0.42998450994491577]},
#  {'sequence': 'call for ethanol blend fuel to go ahead',
#   'labels': ['positive', 'negative'],
#   'scores': [0.9157695770263672, 0.08423039317131042]},
#  {'sequence': 'carews freak goal leaves roma in ruins',
#   'labels': ['negative', 'positive'],
#   'scores': [0.9926269054412842, 0.007373052183538675]},
#  {'sequence': 'cemeteries miss out on funds',
#   'labels': ['negative', 'positive'],
#   'scores': [0.992743968963623, 0.007256054785102606]},
#  {'sequence': 'code of conduct toughens organ donation regulations',
#   'labels': ['negative', 'positive'],
#   'scores': [0.7687487602233887, 0.23125125467777252]},
#  {'sequence': 'commonwealth bank cuts fixed home loan rates',
#   'labels': ['positive', 'negative'],
#   'scores': [0.7199854254722595, 0.28001460433006287]},
#  {'sequence': 'community urged to help homeless youth',
#   'labels': ['positive', 'negative'],
#   'scores': [0.8149281144142151, 0.18507187068462372]},
#  {'sequence': 'council chief executive fails to secure position',
#   'labels': ['negative', 'positive'],
#   'scores': [0.9956163763999939, 0.004383575636893511]},
#  {'sequence': 'councillor to contest wollongong as independent',
#   'labels': ['positive', 'negative'],
#   'scores': [0.5315107703208923, 0.46848925948143005]},
#  {'sequence': 'council moves to protect tas heritage garden',
#   'labels': ['positive', 'negative'],
#   'scores': [0.825962483882904, 0.17403747141361237]},
#  {'sequence': 'council welcomes ambulance levy decision',
#   'labels': ['positive', 'negative'],
#   'scores': [0.9826608300209045, 0.017339181154966354]},
#  {'sequence': 'council welcomes insurance breakthrough',
#   'labels': ['positive', 'negative'],
#   'scores': [0.995387852191925, 0.0046121468767523766]},
#  {'sequence': 'crean tells alp leadership critics to shut up',
#   'labels': ['negative', 'positive'],
#   'scores': [0.9307281374931335, 0.06927183270454407]},
#  {'sequence': 'dargo fire threat expected to rise',
#   'labels': ['negative', 'positive'],
#   'scores': [0.9554483890533447, 0.0445515513420105]},
#  {'sequence': 'death toll continues to climb in south korean subway',
#   'labels': ['negative', 'positive'],
#   'scores': [0.9942945837974548, 0.005705447867512703]},
#  {'sequence': 'dems hold plebiscite over iraqi conflict',
#   'labels': ['negative', 'positive'],
#   'scores': [0.7061217427253723, 0.2938782870769501]},
#  {'sequence': 'dent downs philippoussis in tie break thriller',
#   'labels': ['negative', 'positive'],
#   'scores': [0.9114633798599243, 0.0885365754365921]},
#  {'sequence': 'de villiers to learn fate on march 5',
#   'labels': ['negative', 'positive'],
#   'scores': [0.921349823474884, 0.07865019142627716]},
#  {'sequence': 'digital tv will become commonplace summit',
#   'labels': ['positive', 'negative'],
#   'scores': [0.8867214322090149, 0.11327853053808212]},
#  {'sequence': 'direct anger at govt not soldiers crean urges',
#   'labels': ['negative', 'positive'],
#   'scores': [0.9689710736274719, 0.03102888911962509]},
#  {'sequence': 'dispute over at smithton vegetable processing plant',
#   'labels': ['negative', 'positive'],
#   'scores': [0.9789462685585022, 0.021053791046142578]},
#  {'sequence': 'dog mauls 18 month old toddler in nsw',
#   'labels': ['negative', 'positive'],
#   'scores': [0.9798578023910522, 0.020142246037721634]},
#  {'sequence': 'dying korean subway passengers phoned for help',
#   'labels': ['negative', 'positive'],
#   'scores': [0.8645918369293213, 0.1354081779718399]},
#  {'sequence': 'england change three for wales match',
#   'labels': ['positive', 'negative'],
#   'scores': [0.6090796589851379, 0.3909202814102173]},
#  {'sequence': 'epa still trying to recover chemical clean up costs',
#   'labels': ['negative', 'positive'],
#   'scores': [0.9303273558616638, 0.06967265903949738]},
#  {'sequence': 'expressions of interest sought to build livestock',
#   'labels': ['positive', 'negative'],
#   'scores': [0.922565221786499, 0.07743477076292038]},
#  {'sequence': 'fed opp to re introduce national insurance',
#   'labels': ['positive', 'negative'],
#   'scores': [0.9402402639389038, 0.059759728610515594]},
#  {'sequence': 'firefighters contain acid spill',
#   'labels': ['negative', 'positive'],
#   'scores': [0.8707419037818909, 0.12925809621810913]},
#  {'sequence': 'four injured in head on highway crash',
#   'labels': ['negative', 'positive'],
#   'scores': [0.9375851154327393, 0.06241487339138985]},
#  {'sequence': 'freedom records net profit for third successive',
#   'labels': ['positive', 'negative'],
#   'scores': [0.9894891381263733, 0.010510900057852268]},
#  {'sequence': 'funds allocated for domestic violence victims',
#   'labels': ['positive', 'negative'],
#   'scores': [0.7944229245185852, 0.2055770307779312]},
#  {'sequence': 'funds allocated for youth at risk',
#   'labels': ['positive', 'negative'],
#   'scores': [0.7061353325843811, 0.2938646078109741]},
#  {'sequence': 'funds announced for bridge work',
#   'labels': ['positive', 'negative'],
#   'scores': [0.828856885433197, 0.17114312946796417]},
#  {'sequence': 'funds to go to cadell upgrade',
#   'labels': ['positive', 'negative'],
#   'scores': [0.7460033893585205, 0.2539966106414795]},
#  {'sequence': 'funds to help restore cossack',
#   'labels': ['positive', 'negative'],
#   'scores': [0.6822203993797302, 0.317779541015625]},
#  {'sequence': 'german court to give verdict on sept 11 accused',
#   'labels': ['negative', 'positive'],
#   'scores': [0.58229660987854, 0.41770339012145996]},
#  {'sequence': 'gilchrist backs rest policy',
#   'labels': ['positive', 'negative'],
#   'scores': [0.7822775840759277, 0.21772243082523346]},
#  {'sequence': 'girl injured in head on highway crash',
#   'labels': ['negative', 'positive'],
#   'scores': [0.8981829881668091, 0.10181701928377151]},
#  {'sequence': 'gold coast to hear about bilby project',
#   'labels': ['positive', 'negative'],
#   'scores': [0.6266319155693054, 0.3733680248260498]},
#  {'sequence': 'golf club feeling smoking ban impact',
#   'labels': ['negative', 'positive'],
#   'scores': [0.5792977213859558, 0.4207022786140442]},
#  {'sequence': 'govt is to blame for ethanols unpopularity opp',
#   'labels': ['negative', 'positive'],
#   'scores': [0.9954107403755188, 0.004589294549077749]},
#  {'sequence': 'greens offer police station alternative',
#   'labels': ['positive', 'negative'],
#   'scores': [0.9397116303443909, 0.06028832867741585]},
#  {'sequence': 'griffiths under fire over project knock back',
#   'labels': ['negative', 'positive'],
#   'scores': [0.9953849911689758, 0.004615032579749823]},
#  {'sequence': 'group to meet in north west wa over rock art',
#   'labels': ['positive', 'negative'],
#   'scores': [0.6069285273551941, 0.3930714428424835]},
#  {'sequence': 'hacker gains access to eight million credit cards',
#   'labels': ['negative', 'positive'],
#   'scores': [0.9247725009918213, 0.07522754371166229]},
#  {'sequence': 'hanson is grossly naive over nsw issues costa',
#   'labels': ['negative', 'positive'],
#   'scores': [0.9837161898612976, 0.016283823177218437]},
#  {'sequence': 'hanson should go back where she came from nsw mp',
#   'labels': ['negative', 'positive'],
#   'scores': [0.9832157492637634, 0.016784261912107468]},
#  {'sequence': 'harrington raring to go after break',
#   'labels': ['positive', 'negative'],
#   'scores': [0.9636269807815552, 0.03637306019663811]},
#  {'sequence': 'health minister backs organ and tissue storage',
#   'labels': ['positive', 'negative'],
#   'scores': [0.9011977910995483, 0.09880225360393524]},
#  {'sequence': 'heavy metal deposits survey nearing end',
#   'labels': ['negative', 'positive'],
#   'scores': [0.6679554581642151, 0.3320446014404297]},
#  {'sequence': 'injured rios pulls out of buenos aires open',
#   'labels': ['positive', 'negative'],
#   'scores': [0.5341265201568604, 0.46587345004081726]},
#  {'sequence': 'inquest finds mans death accidental',
#   'labels': ['negative', 'positive'],
#   'scores': [0.9370743036270142, 0.06292568892240524]},
#  {'sequence': 'investigations underway into death toll of korean',
#   'labels': ['negative', 'positive'],
#   'scores': [0.8712455630302429, 0.12875443696975708]},
#  {'sequence': 'investigation underway into elster creek spill',
#   'labels': ['negative', 'positive'],
#   'scores': [0.8518007397651672, 0.14819929003715515]},
#  {'sequence': 'iraqs neighbours plead for continued un inspections',
#   'labels': ['negative', 'positive'],
#   'scores': [0.8583927750587463, 0.14160722494125366]},
#  {'sequence': 'iraq to pay for own rebuilding white house',
#   'labels': ['negative', 'positive'],
#   'scores': [0.7619945406913757, 0.2380053997039795]},
#  {'sequence': 'irish man arrested over omagh bombing',
#   'labels': ['negative', 'positive'],
#   'scores': [0.8402900695800781, 0.15970996022224426]},
#  {'sequence': 'irrigators vote over river management',
#   'labels': ['negative', 'positive'],
#   'scores': [0.8486306071281433, 0.15136945247650146]},
#  {'sequence': 'israeli forces push into gaza strip',
#   'labels': ['negative', 'positive'],
#   'scores': [0.9085285067558289, 0.09147149324417114]},
#  {'sequence': 'jury to consider verdict in murder case',
#   'labels': ['negative', 'positive'],
#   'scores': [0.7507734298706055, 0.24922655522823334]},
#  {'sequence': 'juvenile sex offenders unlikely to reoffend as',
#   'labels': ['negative', 'positive'],
#   'scores': [0.6584975719451904, 0.3415023982524872]},
#  {'sequence': 'kelly disgusted at alleged bp ethanol scare',
#   'labels': ['negative', 'positive'],
#   'scores': [0.9960262775421143, 0.00397369172424078]},
#  {'sequence': 'kelly not surprised ethanol confidence low',
#   'labels': ['negative', 'positive'],
#   'scores': [0.9916743040084839, 0.008325709030032158]},
#  {'sequence': 'korean subway fire 314 still missing',
#   'labels': ['negative', 'positive'],
#   'scores': [0.9567163586616516, 0.04328363388776779]},
#  {'sequence': 'last minute call hands alinghi big lead',
#   'labels': ['positive', 'negative'],
#   'scores': [0.9547697305679321, 0.04523029178380966]},
#  {'sequence': 'low demand forces air service cuts',
#   'labels': ['negative', 'positive'],
#   'scores': [0.9896359443664551, 0.010364031419157982]},
#  {'sequence': 'man arrested after central qld hijack attempt',
#   'labels': ['negative', 'positive'],
#   'scores': [0.7634454965591431, 0.23655451834201813]},
#  {'sequence': 'man charged over cooma murder',
#   'labels': ['negative', 'positive'],
#   'scores': [0.9197967052459717, 0.08020326495170593]},
#  {'sequence': 'man fined after aboriginal tent embassy raid',
#   'labels': ['negative', 'positive'],
#   'scores': [0.944241464138031, 0.055758532136678696]},
#  {'sequence': 'man jailed over keno fraud',
#   'labels': ['negative', 'positive'],
#   'scores': [0.9352292418479919, 0.06477075070142746]},
#  {'sequence': 'man with knife hijacks light plane',
#   'labels': ['negative', 'positive'],
#   'scores': [0.9526265859603882, 0.04737338796257973]},
#  {'sequence': 'martin to lobby against losing nt seat in fed',
#   'labels': ['negative', 'positive'],
#   'scores': [0.8576207160949707, 0.14237922430038452]},
#  {'sequence': 'massive drug crop discovered in western nsw',
#   'labels': ['negative', 'positive'],
#   'scores': [0.7976880669593811, 0.2023119032382965]},
#  {'sequence': 'mayor warns landfill protesters',
#   'labels': ['negative', 'positive'],
#   'scores': [0.9630140066146851, 0.03698597103357315]},
#  {'sequence': 'meeting to consider tick clearance costs',
#   'labels': ['negative', 'positive'],
#   'scores': [0.8447351455688477, 0.15526485443115234]},
#  {'sequence': 'meeting to focus on broken hill water woes',
#   'labels': ['negative', 'positive'],
#   'scores': [0.9590802192687988, 0.04091976210474968]},
#  {'sequence': 'moderate lift in wages growth',
#   'labels': ['positive', 'negative'],
#   'scores': [0.9904953241348267, 0.009504664689302444]},
#  {'sequence': 'more than 40 pc of young men drink alcohol at',
#   'labels': ['negative', 'positive'],
#   'scores': [0.625575840473175, 0.37442412972450256]},
#  {'sequence': 'more water restrictions predicted for northern tas',
#   'labels': ['negative', 'positive'],
#   'scores': [0.9818726181983948, 0.018127350136637688]}]
